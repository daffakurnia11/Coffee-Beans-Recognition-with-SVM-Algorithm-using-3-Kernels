# %%
import cv2
import glob
import matplotlib.pyplot as plt
import os,glob
import os
from os import listdir,makedirs
from os.path import isfile,join
import skimage
from skimage import data
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image

dir_path = "C:/Users/LnData User/Documents/SEMESTER 7/FP SIFON/Coffee Beans Classification/Dataset/Tidak Cacad/"

# %%
# load image Cacat1.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent1.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad1_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad1_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad1_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad1_90.png')

# %%
# load image Cacat2.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent2.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad2_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad2_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad2_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad2_90.png')

# %%
# load image Cacat3.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent3.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad3_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad3_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad3_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad3_90.png')

# %%
# load image Cacat4.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent4.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad4_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad4_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad4_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad4_90.png')

# %%
# load image Cacat5.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent5.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad5_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad5_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad5_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad5_90.png')

# %%
# load image Cacat6.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent6.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad6_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad6_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad6_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad6_90.png')

# %%
# load image Cacat7.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent7.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad7_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad7_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad7_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad7_90.png')

# %%
# load image Cacat8.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent8.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad8_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad8_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad8_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad8_90.png')

# %%
# load image Cacat9.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent9.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad9_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad9_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad9_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad9_90.png')

# %%
# load image Cacat10.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent10.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad10_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad10_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad10_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad10_90.png')

# %%
# load image Cacat11.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent11.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad11_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad11_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad11_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad11_90.png')

# %%
# load image Cacat12.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent12.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad12_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad12_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad12_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad12_90.png')

# %%
# load image Cacat13.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent13.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad13_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad13_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad13_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad13_90.png')

# %%
# load image Cacat14.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent14.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad14_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad14_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad14_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad14_90.png')

# %%
# load image Cacat15.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent15.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad15_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad15_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad15_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad15_90.png')

# %%
# load image Cacat16.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent16.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad16_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad16_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad16_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad16_90.png')

# %%
# load image Cacat17.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent17.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad17_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad17_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad17_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad17_90.png')

# %%
# load image Cacat18.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent18.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad18_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad18_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad18_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad18_90.png')

# %%
# load image Cacat19.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent19.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad19_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad19_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad19_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad19_90.png')

# %%
# load image Cacat20.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent20.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad20_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad20_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad20_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad20_90.png')

# %%
# load image Cacat21.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent21.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad21_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad21_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad21_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad21_90.png')

# %%
# load image Cacat22.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent22.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad22_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad22_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad22_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad22_90.png')

# %%
# load image Cacat23.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent23.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad23_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad23_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad23_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad23_90.png')

# %%
# load image Cacat24.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent24.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad24_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad24_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad24_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad24_90.png')

# %%
# load image Cacat25.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent25.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad25_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad25_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad25_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad25_90.png')

# %%
# load image Cacat26.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent26.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad26_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad26_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad26_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad26_90.png')

# %%
# load image Cacat27.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent27.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad27_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad27_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad27_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad27_90.png')

# %%
# load image Cacat28.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent28.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad28_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad28_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad28_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad28_90.png')

# %%
# load image Cacat29.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent29.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad29_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad29_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad29_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad29_90.png')

# %%
# load image Cacat30.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent30.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad30_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad30_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad30_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad30_90.png')

# %%
# load image Cacat31.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent31.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad31_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad31_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad31_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad31_90.png')

# %%
# load image Cacat32.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent32.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad32_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad32_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad32_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad32_90.png')

# %%
# load image Cacat33.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent33.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad33_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad33_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad33_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad33_90.png')

# %%
# load image Cacat34.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent34.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad34_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad34_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad34_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad34_90.png')

# %%
# load image Cacat35.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent35.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad35_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad35_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad35_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad35_90.png')

# %%
# load image Cacat36.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent36.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad36_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad36_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad36_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad36_90.png')

# %%
# load image Cacat37.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent37.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad37_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad37_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad37_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad37_90.png')

# %%
# load image Cacat38.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent38.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad38_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad38_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad38_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad38_90.png')

# %%
# load image Cacat39.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent39.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad39_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad39_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad39_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad39_90.png')

# %%
# load image Cacat40.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent40.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad40_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad40_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad40_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad40_90.png')

# %%
# load image Cacat41.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent41.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad41_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad41_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad41_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad41_90.png')

# %%
# load image Cacat42.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent42.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad42_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad42_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad42_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad42_90.png')

# %%
# load image Cacat43.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent43.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad43_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad43_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad43_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad43_90.png')

# %%
# load image Cacat44.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent44.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad44_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad44_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad44_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad44_90.png')

# %%
# load image Cacat45.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent45.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad45_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad45_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad45_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad45_90.png')

# %%
# load image Cacat46.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent46.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad46_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad46_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad46_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad46_90.png')

# %%
# load image Cacat47.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent47.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad47_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad47_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad47_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad47_90.png')

# %%
# load image Cacat48.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent48.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad48_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad48_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad48_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad48_90.png')

# %%
# load image Cacat49.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent49.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad49_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad49_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad49_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad49_90.png')

# %%
# load image Cacat50.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent50.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad50_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad50_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad50_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad50_90.png')

# %%
# load image Cacat51.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent51.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad51_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad51_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad51_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad51_90.png')

# %%
# load image Cacat52.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent52.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad52_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad52_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad52_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad52_90.png')

# %%
# load image Cacat53.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent53.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad53_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad53_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad53_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad53_90.png')

# %%
# load image Cacat54.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent54.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad54_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad54_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad54_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad54_90.png')

# %%
# load image Cacat55.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent55.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad55_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad55_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad55_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad55_90.png')

# %%
# load image Cacat56.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent56.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad56_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad56_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad56_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad56_90.png')

# %%
# load image Cacat57.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent57.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad57_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad57_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad57_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad57_90.png')

# %%
# load image Cacat58.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent58.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad58_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad58_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad58_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad58_90.png')

# %%
# load image Cacat59.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent59.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad59_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad59_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad59_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad59_90.png')

# %%
# load image Cacat60.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent60.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad60_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad60_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad60_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad60_90.png')

# %%
# load image Cacat61.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent61.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad61_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad61_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad61_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad61_90.png')

# %%
# load image Cacat62.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent62.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad62_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad62_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad62_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad62_90.png')

# %%
# load image Cacat63.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent63.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad63_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad63_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad63_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad63_90.png')

# %%
# load image Cacat64.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent64.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad64_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad64_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad64_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad64_90.png')

# %%
# load image Cacat65.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent65.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad65_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad65_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad65_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad65_90.png')

# %%
# load image Cacat66.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent66.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad66_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad66_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad66_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad66_90.png')

# %%
# load image Cacat67.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent67.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad67_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad67_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad67_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad67_90.png')

# %%
# load image Cacat68.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent68.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad68_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad68_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad68_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad68_90.png')

# %%
# load image Cacat69.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent69.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad69_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad69_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad69_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad69_90.png')

# %%
# load image Cacat70.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent70.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad70_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad70_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad70_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad70_90.png')

# %%
# load image Cacat71.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent71.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad71_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad71_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad71_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad71_90.png')

# %%
# load image Cacat72.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent72.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad72_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad72_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad72_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad72_90.png')

# %%
# load image Cacat73.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent73.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad73_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad73_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad73_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad73_90.png')

# %%
# load image Cacat74.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent74.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad74_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad74_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad74_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad74_90.png')

# %%
# load image Cacat75.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent75.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad75_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad75_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad75_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad75_90.png')

# %%
# load image Cacat76.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent76.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad76_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad76_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad76_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad76_90.png')

# %%
# load image Cacat77.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent77.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad77_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad77_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad77_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad77_90.png')

# %%
# load image Cacat78.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent78.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad78_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad78_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad78_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad78_90.png')

# %%
# load image Cacat79.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent79.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad79_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad79_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad79_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad79_90.png')

# %%
# load image Cacat80.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent80.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad80_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad80_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad80_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad80_90.png')

# %%
# load image Cacat81.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent81.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad81_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad81_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad81_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad81_90.png')

# %%
# load image Cacat82.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent82.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad82_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad82_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad82_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad82_90.png')

# %%
# load image Cacat83.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent83.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad83_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad83_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad83_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad83_90.png')

# %%
# load image Cacat84.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent84.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad84_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad84_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad84_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad84_90.png')

# %%
# load image Cacat85.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent85.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad85_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad85_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad85_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad85_90.png')

# %%
# load image Cacat86.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent86.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad86_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad86_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad86_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad86_90.png')

# %%
# load image Cacat87.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent87.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad87_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad87_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad87_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad87_90.png')

# %%
# load image Cacat88.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent88.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad88_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad88_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad88_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad88_90.png')

# %%
# load image Cacat89.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent89.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad89_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad89_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad89_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad89_90.png')

# %%
# load image Cacat90.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent90.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad90_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad90_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad90_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad90_90.png')

# %%
# load image Cacat91.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent91.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad91_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad91_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad91_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad91_90.png')

# %%
# load image Cacat92.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent92.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad92_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad92_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad92_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad92_90.png')

# %%
# load image Cacat93.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent93.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad93_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad93_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad93_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad93_90.png')

# %%
# load image Cacat94.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent94.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad94_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad94_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad94_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad94_90.png')

# %%
# load image Cacat95.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent95.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad95_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad95_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad95_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad95_90.png')

# %%
# load image Cacat96.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent96.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad96_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad96_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad96_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad96_90.png')

# %%
# load image Cacat97.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent97.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad97_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad97_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad97_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad97_90.png')

# %%
# load image Cacat98.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent98.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad98_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad98_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad98_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad98_90.png')

# %%
# load image Cacat99.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent99.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad99_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad99_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad99_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad99_90.png')

# %%
# load image Cacat100.png from directory
image = Image.open(f'{dir_path}Transparent/Tidak Cacad_transparent100.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Tidak Cacad100_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Tidak Cacad100_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Tidak Cacad100_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Tidak Cacad100_90.png')
