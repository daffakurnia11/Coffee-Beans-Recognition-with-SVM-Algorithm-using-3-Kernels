# %% [markdown]
# # Importing required libraries

# %%
import cv2
import glob
import matplotlib.pyplot as plt
import os,glob
import os
from os import listdir,makedirs
from os.path import isfile,join
import skimage
from skimage import data
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image

dir_path = "C:/Users/LnData User/Documents/SEMESTER 7/FP SIFON/Coffee Beans Classification/Dataset/Cacad/"

# %% [markdown]
# # Load the image

# %%
# load image Cacad1.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent1.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad1_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad1_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad1_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad1_90.png')

# %%
# load image Cacad2.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent2.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad2_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad2_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad2_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad2_90.png')

# %%
# load image Cacad3.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent3.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad3_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad3_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad3_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad3_90.png')

# %%
# load image Cacad4.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent4.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad4_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad4_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad4_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad4_90.png')

# %%
# load image Cacad5.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent5.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad5_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad5_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad5_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad5_90.png')

# %%
# load image Cacad6.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent6.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad6_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad6_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad6_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad6_90.png')

# %%
# load image Cacad7.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent7.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad7_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad7_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad7_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad7_90.png')

# %%
# load image Cacad8.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent8.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad8_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad8_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad8_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad8_90.png')

# %%
# load image Cacad9.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent9.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad9_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad9_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad9_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad9_90.png')

# %%
# load image Cacad10.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent10.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad10_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad10_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad10_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad10_90.png')

# %%
# load image Cacad11.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent11.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad11_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad11_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad11_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad11_90.png')

# %%
# load image Cacad12.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent12.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad12_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad12_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad12_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad12_90.png')

# %%
# load image Cacad13.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent13.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad13_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad13_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad13_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad13_90.png')

# %%
# load image Cacad14.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent14.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad14_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad14_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad14_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad14_90.png')

# %%
# load image Cacad15.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent15.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad15_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad15_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad15_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad15_90.png')

# %%
# load image Cacad16.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent16.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad16_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad16_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad16_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad16_90.png')

# %%
# load image Cacad17.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent17.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad17_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad17_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad17_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad17_90.png')

# %%
# load image Cacad18.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent18.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad18_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad18_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad18_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad18_90.png')

# %%
# load image Cacad19.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent19.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad19_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad19_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad19_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad19_90.png')

# %%
# load image Cacad20.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent20.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad20_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad20_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad20_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad20_90.png')

# %%
# load image Cacad21.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent21.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad21_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad21_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad21_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad21_90.png')

# %%
# load image Cacad22.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent22.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad22_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad22_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad22_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad22_90.png')

# %%
# load image Cacad23.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent23.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad23_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad23_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad23_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad23_90.png')

# %%
# load image Cacad24.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent24.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad24_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad24_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad24_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad24_90.png')

# %%
# load image Cacad25.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent25.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad25_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad25_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad25_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad25_90.png')

# %%
# load image Cacad26.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent26.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad26_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad26_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad26_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad26_90.png')

# %%
# load image Cacad27.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent27.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad27_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad27_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad27_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad27_90.png')

# %%
# load image Cacad28.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent28.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad28_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad28_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad28_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad28_90.png')

# %%
# load image Cacad29.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent29.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad29_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad29_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad29_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad29_90.png')

# %%
# load image Cacad30.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent30.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad30_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad30_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad30_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad30_90.png')

# %%
# load image Cacad31.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent31.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad31_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad31_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad31_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad31_90.png')

# %%
# load image Cacad32.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent32.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad32_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad32_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad32_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad32_90.png')

# %%
# load image Cacad33.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent33.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad33_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad33_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad33_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad33_90.png')

# %%
# load image Cacad34.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent34.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad34_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad34_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad34_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad34_90.png')

# %%
# load image Cacad35.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent35.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad35_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad35_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad35_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad35_90.png')

# %%
# load image Cacad36.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent36.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad36_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad36_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad36_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad36_90.png')

# %%
# load image Cacad37.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent37.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad37_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad37_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad37_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad37_90.png')

# %%
# load image Cacad38.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent38.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad38_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad38_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad38_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad38_90.png')

# %%
# load image Cacad39.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent39.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad39_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad39_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad39_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad39_90.png')

# %%
# load image Cacad40.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent40.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad40_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad40_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad40_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad40_90.png')

# %%
# load image Cacad41.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent41.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad41_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad41_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad41_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad41_90.png')

# %%
# load image Cacad42.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent42.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad42_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad42_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad42_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad42_90.png')

# %%
# load image Cacad43.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent43.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad43_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad43_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad43_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad43_90.png')

# %%
# load image Cacad44.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent44.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad44_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad44_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad44_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad44_90.png')

# %%
# load image Cacad45.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent45.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad45_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad45_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad45_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad45_90.png')

# %%
# load image Cacad46.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent46.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad46_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad46_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad46_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad46_90.png')

# %%
# load image Cacad47.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent47.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad47_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad47_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad47_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad47_90.png')

# %%
# load image Cacad48.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent48.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad48_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad48_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad48_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad48_90.png')

# %%
# load image Cacad49.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent49.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad49_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad49_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad49_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad49_90.png')

# %%
# load image Cacad50.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent50.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad50_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad50_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad50_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad50_90.png')

# %%
# load image Cacad51.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent51.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad51_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad51_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad51_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad51_90.png')

# %%
# load image Cacad52.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent52.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad52_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad52_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad52_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad52_90.png')

# %%
# load image Cacad53.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent53.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad53_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad53_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad53_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad53_90.png')

# %%
# load image Cacad54.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent54.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad54_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad54_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad54_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad54_90.png')

# %%
# load image Cacad55.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent55.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad55_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad55_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad55_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad55_90.png')

# %%
# load image Cacad56.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent56.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad56_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad56_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad56_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad56_90.png')

# %%
# load image Cacad57.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent57.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad57_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad57_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad57_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad57_90.png')

# %%
# load image Cacad58.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent58.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad58_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad58_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad58_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad58_90.png')

# %%
# load image Cacad59.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent59.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad59_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad59_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad59_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad59_90.png')

# %%
# load image Cacad60.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent60.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad60_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad60_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad60_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad60_90.png')

# %%
# load image Cacad61.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent61.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad61_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad61_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad61_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad61_90.png')

# %%
# load image Cacad62.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent62.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad62_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad62_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad62_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad62_90.png')

# %%
# load image Cacad63.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent63.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad63_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad63_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad63_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad63_90.png')

# %%
# load image Cacad64.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent64.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad64_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad64_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad64_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad64_90.png')

# %%
# load image Cacad65.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent65.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad65_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad65_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad65_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad65_90.png')

# %%
# load image Cacad66.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent66.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad66_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad66_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad66_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad66_90.png')

# %%
# load image Cacad67.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent67.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad67_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad67_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad67_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad67_90.png')

# %%
# load image Cacad68.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent68.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad68_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad68_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad68_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad68_90.png')

# %%
# load image Cacad69.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent69.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad69_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad69_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad69_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad69_90.png')

# %%
# load image Cacad70.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent70.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad70_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad70_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad70_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad70_90.png')

# %%
# load image Cacad71.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent71.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad71_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad71_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad71_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad71_90.png')

# %%
# load image Cacad72.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent72.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad72_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad72_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad72_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad72_90.png')

# %%
# load image Cacad73.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent73.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad73_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad73_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad73_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad73_90.png')

# %%
# load image Cacad74.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent74.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad74_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad74_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad74_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad74_90.png')

# %%
# load image Cacad75.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent75.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad75_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad75_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad75_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad75_90.png')

# %%
# load image Cacad76.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent76.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad76_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad76_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad76_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad76_90.png')

# %%
# load image Cacad77.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent77.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad77_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad77_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad77_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad77_90.png')

# %%
# load image Cacad78.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent78.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad78_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad78_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad78_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad78_90.png')

# %%
# load image Cacad79.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent79.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad79_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad79_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad79_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad79_90.png')

# %%
# load image Cacad80.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent80.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad80_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad80_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad80_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad80_90.png')

# %%
# load image Cacad81.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent81.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad81_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad81_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad81_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad81_90.png')

# %%
# load image Cacad82.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent82.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad82_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad82_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad82_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad82_90.png')

# %%
# load image Cacad83.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent83.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad83_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad83_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad83_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad83_90.png')

# %%
# load image Cacad84.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent84.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad84_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad84_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad84_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad84_90.png')

# %%
# load image Cacad85.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent85.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad85_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad85_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad85_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad85_90.png')

# %%
# load image Cacad86.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent86.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad86_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad86_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad86_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad86_90.png')

# %%
# load image Cacad87.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent87.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad87_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad87_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad87_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad87_90.png')

# %%
# load image Cacad88.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent88.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad88_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad88_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad88_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad88_90.png')

# %%
# load image Cacad89.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent89.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad89_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad89_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad89_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad89_90.png')

# %%
# load image Cacad90.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent90.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad90_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad90_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad90_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad90_90.png')

# %%
# load image Cacad91.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent91.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad91_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad91_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad91_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad91_90.png')

# %%
# load image Cacad92.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent92.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad92_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad92_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad92_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad92_90.png')

# %%
# load image Cacad93.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent93.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad93_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad93_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad93_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad93_90.png')

# %%
# load image Cacad94.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent94.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad94_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad94_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad94_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad94_90.png')

# %%
# load image Cacad95.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent95.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad95_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad95_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad95_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad95_90.png')

# %%
# load image Cacad96.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent96.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad96_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad96_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad96_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad96_90.png')

# %%
# load image Cacad97.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent97.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad97_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad97_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad97_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad97_90.png')

# %%
# load image Cacad98.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent98.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad98_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad98_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad98_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad98_90.png')

# %%
# load image Cacad99.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent99.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad99_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad99_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad99_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad99_90.png')

# %%
# load image Cacad100.png from directory
image = Image.open(f'{dir_path}Transparent/Cacad_transparent100.png')

# rotating image in 30 degrees
image_rot_30 = image.rotate(30)
image_rot_30.save(f'{dir_path}Augmentation/Cacad100_30.png')

# rotating image in 45 degrees
image_rot_45 = image.rotate(45)
image_rot_45.save(f'{dir_path}Augmentation/Cacad100_45.png')

# rotating image in 60 degrees
image_rot_60 = image.rotate(60)
image_rot_60.save(f'{dir_path}Augmentation/Cacad100_60.png')

# rotating image in 90 degrees
image_rot_90 = image.rotate(90)
image_rot_90.save(f'{dir_path}Augmentation/Cacad100_90.png')
